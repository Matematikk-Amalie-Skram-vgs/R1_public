# %% [markdown]
# ## Halveringsmetoden - oppgave 1.75
# Bruk informasjon som du finner på følgende lenker:
# https://github.com/PGelisa/AmalieSkram1T/blob/master/22-23/Halveringsmetoden.ipynb
#
# https://github.com/PGelisa/AmalieSkram1T/blob/master/22-23/2023InnleveringHalveringsmetoden_nullpunkt-L%C3%98SNING.ipynb

# %% [markdown]
# På disse to sidene finner du tips til hvordan du kan løse oppgave 1.75 ved halveringsmetoden. Importer nødvendige biblioteker, skriv inn den koden du trenger, og løs oppgaven:
#
# ![image.png](attachment:d6e78678-e1f1-4e32-abab-ee2e025c20d5.png)

# %% [markdown]
# 💡 Hint: Det kan være lurt å plotte en graf for å finne intervallene...
#
# Starten på oppgaven er skrevet inn i kodecellen under:

# %%
import numpy as np
import math

def f(x):
    return 0.5x**3 - (2x**2 - 1)
